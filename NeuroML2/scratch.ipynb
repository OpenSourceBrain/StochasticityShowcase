# %%
from pyneuroml import pynml
# %matplotlib inline

# %% [markdown]
# ### Gaussian process
# Dark Blue: Square current pulse<br>
# Green: $\mu = 0.15 nA$, $\sigma = 0.1 nA$, $dt=1 ms$<br>
# Red: $\mu = 0.15 nA$, $\sigma = 0.1 nA$, $dt=5 ms$<br>
# Light Blue: $\mu = 0.15 nA$, $\sigma = 0.1 nA$, $dt=10 ms$<br>

# %%
pynml.run_lems_with_jneuroml('LEMS_NoisyCurrentInput.xml',nogui=True,load_saved_data=True,plot=True);
# Out:
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_NoisyCurrentInput.xml (/home/padraig/neuroConstruct/osb/showcase/StochasticityShowcase/NeuroML2/LEMS_NoisyCurrentInput.xml), base_dir: ., cwd: /home/padraig/neuroConstruct/osb/showcase/StochasticityShowcase/NeuroML2
# pyNeuroML >>> Reloading: Data loaded from ./v.dat (jNeuroML)

# %% [markdown]
# ### Ornstein-Uhlenbeck process
# Dark Blue: Square current pulse<br>
# Green: $\mu = 0.15 nA$, $\sigma = 0.01 nA/ms$, $\tau = 1 ms$, $dt=1 ms$<br>
# Red: $\mu = 0.15 nA$, $\sigma = 0.01 nA/ms$, $\tau = 5 ms$, $dt=1 ms$<br>
# Light Blue: $\mu = 0.15 nA$, $\sigma = 0.01 nA/ms$, $\tau = 25 ms$, $dt=1 ms$<br>

# %%
pynml.run_lems_with_jneuroml('LEMS_OUCurrentInput.xml',nogui=True,load_saved_data=True,plot=True);
# Out:
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_OUCurrentInput.xml (/home/padraig/neuroConstruct/osb/showcase/StochasticityShowcase/NeuroML2/LEMS_OUCurrentInput.xml), base_dir: ., cwd: /home/padraig/neuroConstruct/osb/showcase/StochasticityShowcase/NeuroML2
# pyNeuroML >>> Reloading: Data loaded from ./v.dat (jNeuroML)
