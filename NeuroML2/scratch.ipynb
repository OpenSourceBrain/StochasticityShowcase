# %%
from pyneuroml import pynml
# %matplotlib inline

# %% [markdown]
# ### Gaussian process
# Blue:   Square current pulse<br>
# Orange: $\mu = 0.25 nA$, $\sigma = 0.1 nA$, $dt=1 ms$<br>
# Green:  $\mu = 0.35 nA$, $\sigma = 0.2 nA$, $dt=2 ms$<br>
# Red:    $\mu = 0.15 nA$, $\sigma = 0.05 nA$, $dt=5 ms$<br>
# Purple: $\mu = 0.55 nA$, $\sigma = 0.05 nA$, $dt=1 ms$<br>

# %%
pynml.run_lems_with_jneuroml('LEMS_NoisyCurrentInput.xml',nogui=True,load_saved_data=True,plot=True);
# Out:
# pyNeuroML >>> INFO - Loading LEMS file: LEMS_NoisyCurrentInput.xml and running with jNeuroML
# pyNeuroML >>> INFO - Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/opt/homebrew/anaconda3/envs/py39n/lib/python3.9/site-packages/pyneuroml/lib/jNeuroML-0.12.2-jar-with-dependencies.jar"  LEMS_NoisyCurrentInput.xml  -nogui -I '') in directory: .
# pyNeuroML >>> INFO - Command completed successfully!
# pyNeuroML >>> WARNING - Reloading: Data loaded from ./v.dat (jNeuroML)

# %% [markdown]
# ### Ornstein-Uhlenbeck process
# Blue: Square current pulse<br>
# Orange: $\mu = 0.15 nA$, $\sigma = 0.01 nA/ms$, $\tau = 1 ms$, $dt=1 ms$<br>
# Green: $\mu = 0.15 nA$, $\sigma = 0.01 nA/ms$, $\tau = 5 ms$, $dt=1 ms$<br>
# Red: $\mu = 0.15 nA$, $\sigma = 0.01 nA/ms$, $\tau = 25 ms$, $dt=1 ms$<br>

# %%
pynml.run_lems_with_jneuroml('LEMS_OUCurrentInput.xml',nogui=True,load_saved_data=True,plot=True);
# Out:
# pyNeuroML >>> INFO - Loading LEMS file: LEMS_OUCurrentInput.xml and running with jNeuroML
# pyNeuroML >>> INFO - Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/opt/homebrew/anaconda3/envs/py39n/lib/python3.9/site-packages/pyneuroml/lib/jNeuroML-0.12.2-jar-with-dependencies.jar"  LEMS_OUCurrentInput.xml  -nogui -I '') in directory: .
# pyNeuroML >>> INFO - Command completed successfully!
# pyNeuroML >>> WARNING - Reloading: Data loaded from ./v.dat (jNeuroML)
